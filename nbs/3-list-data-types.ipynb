# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002" # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint)
print("ok",response.ok)
if response.ok:
    data = response.json()
    pprint(data)
# Out:
# ok True
# [{'avg_duration': 2384.6428571428573,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 14,
#   'operating_system': 'Android',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2283.6111111111113,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 18,
#   'operating_system': 'Android',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 3221.1428571428573,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 14,
#   'operating_system': 'Android',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2378.9565217391305,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 23,
#   'operating_system': 'Android',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2352.875,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 16,
#   'operating_system': 'Android',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2804.8125,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 16,
#   'operating_system': 'Android',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2908.05,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 20,
#   'operating_system': 'Android',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2204.1428571428573,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 7,
#   'operating_system': 'Android',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2121.3125,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 16,
#   'operating_system': 'Android',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2276.5,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 24,
#   'operating_system': 'Android',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2701.6216216216217,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 37,
#   'operating_system': 'Linux',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2814.063829787234,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 47,
#   'operating_system': 'Linux',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2223.2380952380954,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 21,
#   'operating_system': 'Linux',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2666.85,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 40,
#   'operating_system': 'Linux',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2902.2702702702704,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 37,
#   'operating_system': 'Linux',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2630.4347826086955,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 23,
#   'operating_system': 'Linux',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 3213.6944444444443,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 36,
#   'operating_system': 'Linux',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2502.269230769231,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 26,
#   'operating_system': 'Linux',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2492.375,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 40,
#   'operating_system': 'Linux',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2064.8275862068967,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 29,
#   'operating_system': 'Linux',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2313.4666666666667,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 30,
#   'operating_system': 'MacOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2550.3225806451615,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 31,
#   'operating_system': 'MacOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2544.409090909091,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 22,
#   'operating_system': 'MacOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2427.769230769231,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 26,
#   'operating_system': 'MacOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2507.1470588235293,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 34,
#   'operating_system': 'MacOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2634.40625,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 32,
#   'operating_system': 'MacOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2379.2413793103447,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 29,
#   'operating_system': 'MacOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2562.8076923076924,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 26,
#   'operating_system': 'MacOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2636.1470588235293,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 34,
#   'operating_system': 'MacOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2829.5,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 30,
#   'operating_system': 'MacOS',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2624.5333333333333,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 15,
#   'operating_system': 'Other',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2107.6,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 5,
#   'operating_system': 'Other',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 3173.1111111111113,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 9,
#   'operating_system': 'Other',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 3028.5,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 8,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2151.285714285714,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 7,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 3096.125,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 8,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 1905.0,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 9,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2805.1111111111113,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 9,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2069.1428571428573,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 7,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2904.1428571428573,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 7,
#   'operating_system': 'Other',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2684.3333333333335,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 48,
#   'operating_system': 'Windows',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2975.392156862745,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 51,
#   'operating_system': 'Windows',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2721.62,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 50,
#   'operating_system': 'Windows',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2460.4736842105262,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 57,
#   'operating_system': 'Windows',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2506.0425531914893,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 47,
#   'operating_system': 'Windows',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2485.4545454545455,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 55,
#   'operating_system': 'Windows',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2422.032786885246,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 61,
#   'operating_system': 'Windows',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2303.26,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 50,
#   'operating_system': 'Windows',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2663.7868852459014,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 61,
#   'operating_system': 'Windows',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2378.8245614035086,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 57,
#   'operating_system': 'Windows',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 3011.230769230769,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 13,
#   'operating_system': 'iOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2351.6,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 20,
#   'operating_system': 'iOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2993.375,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 16,
#   'operating_system': 'iOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2392.6666666666665,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 21,
#   'operating_system': 'iOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 3265.5,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 18,
#   'operating_system': 'iOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2133.96,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 25,
#   'operating_system': 'iOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2996.5,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 24,
#   'operating_system': 'iOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 3047.05,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 20,
#   'operating_system': 'iOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2733.7083333333335,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 24,
#   'operating_system': 'iOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2691.625,
#   'bucket': '2025-08-27T00:00:00Z',
#   'count': 16,
#   'operating_system': 'iOS',
#   'page': '/signup',
#   'ua': ''}]

# %%
detail_path = "/api/events/4"
detail_endpoint = f"{base_url}{detail_path}"
r = requests.get(detail_endpoint)
print('ok', r.status_code)
if r.ok:
    data = r.json()
    pprint(data)
# Out:
# ok 200
# {'duration': 3395,
#  'id': 4,
#  'ip_address': '23.177.184.93',
#  'page': '/about',
#  'referrer': 'https://linkedin.com',
#  'session_id': '53f04f53-aff3-4d15-8c3c-eccb536dbcd0',
#  'time': '2025-08-27T21:24:00.479231Z',
#  'user_agent': 'Opera/8.50.(Windows NT 5.01; be-BY) Presto/2.9.161 '
#                'Version/11.00'}
